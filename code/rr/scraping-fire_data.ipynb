# %% [markdown]
# ## NIFC Wildfire Statistics

# %% [markdown]
# https://www.nifc.gov/fire-information/statistics/wildfires

# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(open("https://www.nifc.gov/fire-information/statistics/wildfires"), "lxml")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2a616b4fa3c7> in <module>
# ----> 1 soup = BeautifulSoup(open("https://www.nifc.gov/fire-information/statistics/wildfires"), "lxml")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://www.nifc.gov/fire-information/statistics/wildfires'
